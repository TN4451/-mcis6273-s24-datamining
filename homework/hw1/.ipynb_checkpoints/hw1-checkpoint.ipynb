# %% [markdown]
# ## HW1 ASSIGNMENT 2

# %% [markdown]
# ### OBJECTIVES

# %% [markdown]
# * Perform basic data engineering and visualization in Python using an external data set.
# * Perform data engineering in Python using OpenAQ API.
# * Perform basic data analysis in Python using OpenAQ weather data.
# * Perform basic statistical significance tests of air quality data.
# * Complete the online HW1 assessment.
# * BONUS: Build and analyze a more complex OpenAQ data set.

# %% [markdown]
# ## Perfom basic data engineering and visualization in Python using an external set data.

# %%
# IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import time
import json 
import os
import folium 
from scipy import stats

# %% [markdown]
# ### § Task: Use Python to make HTTP/API calls to obtain and prepare data.

# %%
## Function to obtain the list of all US airports
def get_airport_data(url):
    # Read the data into the data frame
    airport_data = pd.read_csv(url)
    # Save data frame to a CSV file 
    airport_data.to_csv('all_us_airports.csv', index=False)

    print("Data saved successfully")

data_url = "https://ourairports.com/countries/US/airports.csv"
get_airport_data(data_url)
# Out:
# Data saved successfully

# %%
US_airport = pd.read_csv("all_us_airports.csv")
US_airport
# Out:
#            id    ident           type  \
# 0        3632     KLAX  large_airport
# 1        3754     KORD  large_airport
# 2        3622     KJFK  large_airport
# 3        3384     KATL  large_airport
# 4        3878     KSFO  large_airport
# ...       ...      ...            ...
# 30930  353111  US-6578         closed
# 30931  322813  US-0527       heliport
# 30932  324916  US-0652       heliport
# 30933  327838  US-0874       heliport
# 30934  336215  US-1675         closed
#
#                                                    name  latitude_deg  \
# 0                     Los Angeles International Airport     33.942501
# 1                  Chicago O'Hare International Airport     41.978600
# 2                  John F Kennedy International Airport     40.639447
# 3      Hartsfield Jackson Atlanta International Airport     33.636700
# 4                   San Francisco International Airport     37.618999
# ...                                                 ...           ...
# 30930                                 Kettenpom Airport     40.160970
# 30931                 AdventHealth Zephyrhills Heliport     28.261934
# 30932                               Rotary Run Heliport     40.605805
# 30933                               Black Rock Heliport     35.084975
# 30934                                    Zzyzx Airstrip     35.143373
#
#        longitude_deg  elevation_ft continent   country_name iso_country  ...  \
# 0        -118.407997         125.0       NaN  United States          US  ...
# 1         -87.904800         672.0       NaN  United States          US  ...
# 2         -73.779317          13.0       NaN  United States          US  ...
# 3         -84.428101        1026.0       NaN  United States          US  ...
# 4        -122.375000          13.0       NaN  United States          US  ...
# ...              ...           ...       ...            ...         ...  ...
# 30930    -123.463850        3408.0       NaN  United States          US  ...
# 30931     -82.185663         160.0       NaN  United States          US  ...
# 30932     -81.415002        1027.0       NaN  United States          US  ...
# 30933    -108.788350        6454.0       NaN  United States          US  ...
# 30934    -116.107035           NaN       NaN  United States          US  ...
#
#         municipality scheduled_service gps_code iata_code  local_code  \
# 0        Los Angeles                 1     KLAX       LAX         LAX
# 1            Chicago                 1     KORD       ORD         ORD
# 2           New York                 1     KJFK       JFK         JFK
# 3            Atlanta                 1     KATL       ATL         ATL
# 4      San Francisco                 1     KSFO       SFO         SFO
# ...              ...               ...      ...       ...         ...
# 30930          Zenia                 0      NaN       NaN         NaN
# 30931    Zephyrhills                 0     FD75       NaN        FD75
# 30932           Zoar                 0      NaN       NaN        0OH2
# 30933           Zuni                 0      NaN       NaN         NM1
# 30934          Zzyzx                 0      NaN       NaN         NaN
#
#                                                home_link  \
# 0                                https://www.flylax.com/
# 1      https://www.flychicago.com/ohare/home/pages/de...
# 2                            https://www.jfkairport.com/
# 3                        http://www.atlanta-airport.com/
# 4                                 http://www.flysfo.com/
# ...                                                  ...
# 30930                                                NaN
# 30931                                                NaN
# 30932                                                NaN
# 30933                                                NaN
# 30934                                                NaN
#
#                                           wikipedia_link  \
# 0      https://en.wikipedia.org/wiki/Los_Angeles_Inte...
# 1      https://en.wikipedia.org/wiki/O'Hare_Internati...
# 2      https://en.wikipedia.org/wiki/John_F._Kennedy_...
# 3      https://en.wikipedia.org/wiki/Hartsfield–Jacks...
# 4      https://en.wikipedia.org/wiki/San_Francisco_In...
# ...                                                  ...
# 30930                                                NaN
# 30931                                                NaN
# 30932                                                NaN
# 30933                                                NaN
# 30934                                                NaN
#
#                                                 keywords    score  \
# 0                                            Tom Bradley  1335475
# 1                                     CHI, Orchard Place  1503175
# 2      Manhattan, New York City, NYC, Idlewild, IDL, ...  1052075
# 3                                                    NaN  2002475
# 4                                               QSF, QBA  1112475
# ...                                                  ...      ...
# 30930                                                NaN        0
# 30931              Florida Hospital Zephyrhills Heliport        0
# 30932                                                NaN        0
# 30933                                                NaN        0
# 30934                                                NaN        0
#
#                     last_updated
# 0      2023-12-21T12:31:02+00:00
# 1      2018-09-16T02:35:35+00:00
# 2      2022-10-18T18:49:55+00:00
# 3      2018-09-19T14:50:01+00:00
# 4      2008-06-13T14:30:04+00:00
# ...                          ...
# 30930  2022-02-28T15:05:57+00:00
# 30931  2021-06-11T17:55:06+00:00
# 30932  2017-09-09T20:04:27+00:00
# 30933  2018-05-15T23:12:01+00:00
# 30934  2020-09-28T10:17:31+00:00
#
# [30935 rows x 23 columns]

# %%
US_airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30935 entries, 0 to 30934
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 30935 non-null  int64
#  1   ident              30935 non-null  object
#  2   type               30935 non-null  object
#  3   name               30935 non-null  object
#  4   latitude_deg       30935 non-null  float64
#  5   longitude_deg      30935 non-null  float64
#  6   elevation_ft       28929 non-null  float64
#  7   continent          110 non-null    object
#  8   country_name       30935 non-null  object
#  9   iso_country        30935 non-null  object
#  10  region_name        30935 non-null  object
#  11  iso_region         30935 non-null  object
#  12  local_region       30935 non-null  object
#  13  municipality       30877 non-null  object
#  14  scheduled_service  30935 non-null  int64
#  15  gps_code           20313 non-null  object
#  16  iata_code          1971 non-null   object
#  17  local_code         21238 non-null  object
#  18  home_link          1162 non-null   object
#  19  wikipedia_link     2591 non-null   object
#  20  keywords           6155 non-null   object
#  21  score              30935 non-null  int64
#  22  last_updated       30935 non-null  object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 5.4+ MB

# %%
# Checking for null values 
US_airport.isnull().sum()
# Out:
# id                       0
# ident                    0
# type                     0
# name                     0
# latitude_deg             0
# longitude_deg            0
# elevation_ft          2006
# continent            30825
# country_name             0
# iso_country              0
# region_name              0
# iso_region               0
# local_region             0
# municipality            58
# scheduled_service        0
# gps_code             10622
# iata_code            28964
# local_code            9697
# home_link            29773
# wikipedia_link       28344
# keywords             24780
# score                    0
# last_updated             0
# dtype: int64

# %%
# We can see that the continent has more NAN values so we are going to remove the column 
US_airport = US_airport.drop('continent', axis = 1)

# %%
# We are also removing the non-essential column from the data frame.
# Like id, iso_country, iso_region, local_region, country_name, last_updated, home link, wikipedia link
US_airport = US_airport.drop(['id', 'country_name','iso_country', 'iso_region', 'local_region', 'home_link', 'wikipedia_link'], axis = 1)

# %%
# Removing NAN value from dataset 
US_airport = US_airport.dropna(subset = ['iata_code'])

# %%
US_airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1971 entries, 0 to 30923
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ident              1971 non-null   object
#  1   type               1971 non-null   object
#  2   name               1971 non-null   object
#  3   latitude_deg       1971 non-null   float64
#  4   longitude_deg      1971 non-null   float64
#  5   elevation_ft       1941 non-null   float64
#  6   region_name        1971 non-null   object
#  7   municipality       1971 non-null   object
#  8   scheduled_service  1971 non-null   int64
#  9   gps_code           1896 non-null   object
#  10  iata_code          1971 non-null   object
#  11  local_code         1957 non-null   object
#  12  keywords           483 non-null    object
#  13  score              1971 non-null   int64
#  14  last_updated       1971 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 246.4+ KB

# %% [markdown]
# ### § Task: Filter data to a subset for further use.

# %%
def filter_large_airports():
    # Load the data from the CSV file
    filtered_data = pd.read_csv('all_us_airports.csv')

    # Filter the data to include only large airports
    filtered_data = filtered_data[filtered_data['type'] == 'large_airport']

    # Select only the relevant columns
    filtered_data = filtered_data[['name', 'latitude_deg', 'longitude_deg', 'iata_code']]

    # Save the filtered data to a new CSV file
    filtered_data.to_csv('large_us_airports.csv', index=False)

    print("Data filtered and saved successfully!")

# Call the function
filter_large_airports()
# Out:
# Data filtered and saved successfully!

# %%
large_airport_data = pd.read_csv("large_us_airports.csv")
large_airport_data
# Out:
#                                                 name  latitude_deg  \
# 0                  Los Angeles International Airport     33.942501
# 1               Chicago O'Hare International Airport     41.978600
# 2               John F Kennedy International Airport     40.639447
# 3   Hartsfield Jackson Atlanta International Airport     33.636700
# 4                San Francisco International Airport     37.618999
# ..                                               ...           ...
# 62                    Portland International Jetport     43.646198
# 63             Orlando Sanford International Airport     28.777599
# 64                   Fairbanks International Airport     64.815102
# 65                   Camarillo International Airport     34.213699
# 66                                Joint Base Andrews     38.810799
#
#     longitude_deg iata_code
# 0     -118.407997       LAX
# 1      -87.904800       ORD
# 2      -73.779317       JFK
# 3      -84.428101       ATL
# 4     -122.375000       SFO
# ..            ...       ...
# 62     -70.309303       PWM
# 63     -81.237503       SFB
# 64    -147.856003       FAI
# 65    -119.094002       NaN
# 66     -76.866997       ADW
#
# [67 rows x 4 columns]

# %%
large_airport_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           67 non-null     object
#  1   latitude_deg   67 non-null     float64
#  2   longitude_deg  67 non-null     float64
#  3   iata_code      66 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 2.2+ KB

# %%
# One of the columns has one NaN value which we will ignore by removing it 
rows_with_nan = large_airport_data[large_airport_data.isna().any(axis = 1)]
print(rows_with_nan)
# Out:
#                                name  latitude_deg  longitude_deg iata_code
# 65  Camarillo International Airport     34.213699    -119.094002       NaN

# %%
# Removing the row with nan value 
large_airport_data = large_airport_data.drop(rows_with_nan.index)
large_airport_data
# Out:
#                                                 name  latitude_deg  \
# 0                  Los Angeles International Airport     33.942501
# 1               Chicago O'Hare International Airport     41.978600
# 2               John F Kennedy International Airport     40.639447
# 3   Hartsfield Jackson Atlanta International Airport     33.636700
# 4                San Francisco International Airport     37.618999
# ..                                               ...           ...
# 61                       Tulsa International Airport     36.198399
# 62                    Portland International Jetport     43.646198
# 63             Orlando Sanford International Airport     28.777599
# 64                   Fairbanks International Airport     64.815102
# 66                                Joint Base Andrews     38.810799
#
#     longitude_deg iata_code
# 0     -118.407997       LAX
# 1      -87.904800       ORD
# 2      -73.779317       JFK
# 3      -84.428101       ATL
# 4     -122.375000       SFO
# ..            ...       ...
# 61     -95.888100       TUL
# 62     -70.309303       PWM
# 63     -81.237503       SFB
# 64    -147.856003       FAI
# 66     -76.866997       ADW
#
# [66 rows x 4 columns]

# %% [markdown]
# ### § Task: Plot the data using Folium

# %%
# Installing Folium 
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/sau24s/lib/python3.8/site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from folium) (1.24.4)
# Requirement already satisfied: requests in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from folium) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from requests->folium) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/sau24s/lib/python3.8/site-packages (from requests->folium) (2023.11.17)

# %%
# Plotting the map 
latitude_longitude = [large_airport_data['latitude_deg'].mean(), large_airport_data['longitude_deg'].mean()]
map = folium.Map(
    location = latitude_longitude,
    zoom_start = 5,
)
# Iterating through the dataset 
for index, row in large_airport_data.iterrows():
    angle = 315
    popup_content = f"{row['name']} ({row['iata_code']})"
    icon_params = {"prefix": "fa", "icon": "plane"}
    icon = folium.Icon(angle = angle, **icon_params)
    folium.Marker(location = [row['latitude_deg'], row['longitude_deg']],
                  popup = popup_content,
                  icon = icon).add_to(map)

map.save('large_airport_map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_031494352d9dc294033fb3974555a290 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_031494352d9dc294033fb3974555a290&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_031494352d9dc294033fb3974555a290 = L.map(
#                 &quot;map_031494352d9dc294033fb3974555a290&quot;,
#                 {
#                     center: [37.491843338035125, -94.27197628926415],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9189d74e4b2b906e3350590d5c8e2a61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9189d74e4b2b906e3350590d5c8e2a61.addTo(map_031494352d9dc294033fb3974555a290);
#
#
#             var marker_4797daaf4e936f048bddfd5dfbdeb1d8 = L.marker(
#                 [33.942501, -118.407997],
#                 {}
#             ).addTo(map_031494352d9dc294033fb3974555a290);
#
#
#             var icon_d892528b99c062d05ab18acfc508c5b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-315&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4797daaf4e936f048bddfd5dfbdeb1d8.setIcon(icon_d892528b99c062d05ab18acfc508c5b1);
#
#
#         var popup_cfe25e50d7e4a9cef7ce4bdc09ec0e07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_313c75209947635c213ac7f4675b1329 = $(`&lt;div id=&quot;html_313c75209947635c213ac7f4675b1329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles International Airport (LAX)&lt;/div&gt;`)[0];
#                 popup_cfe25e50d7e4a9cef7ce4bdc09ec0e07.setContent(html_313c75209947635c213ac7f4675b1329);
#
#
#
#         marker_4797daaf4e936f048bddfd5dfbdeb1d8.bindPopup(popup_cfe25e50d7e4a9cef7ce4bdc09ec0e07)
#         ;
#
#
#
#
#             var marker_015d43bc8d726d6425abdc03a3332fa2 = L.marker(
#                 [41.9786, -87.9048],
#                 {}
#             ).addTo(map_031494352d9dc294033fb3974555a290);
#
#
#             var icon_8cdaa6383deac5764d4eb4aed701e487 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-315&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_015d43bc8d726d6425abdc03a3332fa2.setIcon(icon_8cdaa6383deac5764d4eb4aed701e487);
#
#
#         var popup_21335118863602d456b807cd58f4a6d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91236ba58ccc2b138e689fddf80437fe = $(`&lt;div id=&quot;html_91236ba58ccc2b138e689fddf80437fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chicago O&#x27;Hare International Airport (ORD)&lt;/div&gt;`)[0];
#                 popup_21335118863602d456b807cd58f4a6d9.setContent(html_91236ba58ccc2b138e689fddf80437fe);
#
#
#
#         marker_015d43bc8d726d6425abdc03a3332fa2.bindPopup(popup_21335118863602d456b807cd58f4a6d9)
#         ;
#
#
#
#
#             var marker_3fb61ec822f69a0fe73ed4a1b1e2d630 = L.marker(
#                 [40.639447, -73.779317],
#                 {}
#             ).addTo(map_031494352d9dc294033fb3974555a290);
#
#
#             var icon_2aedcc5dcf1dc6b53fb6dc52d57bcec7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-315&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3fb61ec822f69a0fe73ed4a1b1e2d630.setIcon(icon_2aedcc5dcf1dc6b53fb6dc52d57bcec7);
#
#
#         var popup_4cc2c5f1823cf6ce8d0d838ea3b5e73c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2d75ab2faf12577f091a0286c2ab6b1 = $(`&lt;div id=&quot;html_e2d75ab2faf12577f091a0286c2ab6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John F Kennedy International Airport (JFK)&lt;/div&gt;`)[0];
#                 popup_4cc2c5f1823cf6ce8d0d838ea3b5e73c.setContent(html_e2d75ab2faf12577f091a0286c2ab6b1);
#
#
#
#         marker_3fb61ec822f69a0fe73ed4a1b1e2d630.bindPopup(popup_4cc2c5f1823cf6ce8d0d838ea3b5e73c)
#         ;
#
#
#
#
#             var marker_e9f96eba3d84b5e47e97ac993debfe91 = L.marker(
#                 [33.6367, -84.428101],
#                 {}
#             ).addTo(map_031494352d9dc294033fb3974555a290);
#
#
#             var icon_1758f77d32e8cd963fea0222818ccedd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-315&quot;, &quot;icon&quo

# %% [markdown]
# ## Perform data engineering in Python using OpenAQ API.

# %% [markdown]
# ### § Task: Obtain a dataset from OpenAQ

# %%
# Function to fetch data 
def fetch_openaq_data(date_from, date_to, coordinates, radius, parameter_id, limit, filename):
    # Define the base URL for the OpenAQ API
    base_url = "https://api.openaq.org/v2/measurements"

    # Define parameters for the API request
    params = {
        "date_from": date_from,
        "date_to": date_to,
        "coordinates": coordinates,
        "radius": radius,
        "parameter_id": parameter_id,
        "limit": limit
    }

    # Define headers for the API request
    headers = {"accept": "application/json"}

    # Send a GET request to the OpenAQ API
    response = requests.get(base_url, params=params, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()

        # Save the data to a JSON file
        with open(filename, 'w') as f:
            json.dump(data, f)
    else:
        print(f"Request failed with status code {response.status_code}")

    # Pause for 1-2 seconds as a courtesy to the OpenAQ API
    time.sleep(2)

# %%
# Call the function for downtown Detroit
fetch_openaq_data("2023-06-06T00:00:00Z", "2023-06-06T23:59:59Z", "42.33143000,-83.04575000", 7500, 2, 10000, 'Downtown_Detroit_Data.json')

# %%
# Function to load JSON file and convert to dataframe
def load_openaq_data(file_path):
    try:
        with open(file_path, 'r') as json_file:
            # Load the JSON data from the file
            data = json.load(json_file)
            
        # Create a DataFrame from the 'results' key in the loaded data
        openaq_data = pd.DataFrame(data['results'])

        return openaq_data

    except FileNotFoundError:
        print(f"File '{file_path}' not found.")
        return None
    except json.JSONDecodeError:
        print(f"Failed to decode JSON from file '{file_path}'.")
        return None

# %%
# Call function on Detroit data 
file_path = 'Downtown_Detroit_Data.json'
Detroit_data = load_openaq_data(file_path)
Detroit_data
# Out:
#       locationId          location parameter  value  \
# 0           1385  Windsor Downtown      pm25  125.0
# 1           1385  Windsor Downtown      pm25   21.0
# 2           1385  Windsor Downtown      pm25   14.0
# 3           1385  Windsor Downtown      pm25   18.0
# 4           1385  Windsor Downtown      pm25   21.0
# ...          ...               ...       ...    ...
# 6279        7002     MILITARY PARK      pm25   33.7
# 6280        7002     MILITARY PARK      pm25   31.7
# 6281        7002     MILITARY PARK      pm25   29.9
# 6282        7002     MILITARY PARK      pm25   28.8
# 6283        7002     MILITARY PARK      pm25   29.8
#
#                                                    date   unit  \
# 0     {'utc': '2023-06-06T23:00:00+00:00', 'local': ...  µg/m³
# 1     {'utc': '2023-06-06T22:00:00+00:00', 'local': ...  µg/m³
# 2     {'utc': '2023-06-06T21:00:00+00:00', 'local': ...  µg/m³
# 3     {'utc': '2023-06-06T20:00:00+00:00', 'local': ...  µg/m³
# 4     {'utc': '2023-06-06T19:00:00+00:00', 'local': ...  µg/m³
# ...                                                 ...    ...
# 6279  {'utc': '2023-06-06T05:00:00+00:00', 'local': ...  µg/m³
# 6280  {'utc': '2023-06-06T04:00:00+00:00', 'local': ...  µg/m³
# 6281  {'utc': '2023-06-06T03:00:00+00:00', 'local': ...  µg/m³
# 6282  {'utc': '2023-06-06T02:00:00+00:00', 'local': ...  µg/m³
# 6283  {'utc': '2023-06-06T01:00:00+00:00', 'local': ...  µg/m³
#
#                                            coordinates country  city  \
# 0         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 1         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 2         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 3         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 4         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# ...                                                ...     ...   ...
# 6279  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6280  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6281  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6282  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6283  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
#
#       isMobile isAnalysis                     entity       sensorType
# 0        False       None  Governmental Organization  reference grade
# 1        False       None  Governmental Organization  reference grade
# 2        False       None  Governmental Organization  reference grade
# 3        False       None  Governmental Organization  reference grade
# 4        False       None  Governmental Organization  reference grade
# ...        ...        ...                        ...              ...
# 6279     False       None  Governmental Organization  reference grade
# 6280     False       None  Governmental Organization  reference grade
# 6281     False       None  Governmental Organization  reference grade
# 6282     False       None  Governmental Organization  reference grade
# 6283     False       None  Governmental Organization  reference grade
#
# [6284 rows x 13 columns]

# %% [markdown]
# ### § Task: Transform, filter and store the OpenAQ data as CSV

# %% [markdown]
# #### Transform

# %%
# Function to convert the coordinates field to two fields: sensor_lat and sensor_lon
def transform_openaq_data(data):
    openaq_data = data.copy()
    openaq_data['sensor_lat'] = openaq_data['coordinates'].apply(lambda x: x['latitude'])
    openaq_data['sensor_lon'] = openaq_data['coordinates'].apply(lambda x: x['longitude'])
    openaq_data['local_time'] = pd.to_datetime(openaq_data['date'].apply(lambda x: x['local']))
    
    # Drop the original 'coordinate' column
    openaq_data.drop(columns=['date'], inplace = True)
    return openaq_data

transformed_detroit_data = transform_openaq_data(Detroit_data)
transformed_detroit_data
# Out:
#       locationId          location parameter  value   unit  \
# 0           1385  Windsor Downtown      pm25  125.0  µg/m³
# 1           1385  Windsor Downtown      pm25   21.0  µg/m³
# 2           1385  Windsor Downtown      pm25   14.0  µg/m³
# 3           1385  Windsor Downtown      pm25   18.0  µg/m³
# 4           1385  Windsor Downtown      pm25   21.0  µg/m³
# ...          ...               ...       ...    ...    ...
# 6279        7002     MILITARY PARK      pm25   33.7  µg/m³
# 6280        7002     MILITARY PARK      pm25   31.7  µg/m³
# 6281        7002     MILITARY PARK      pm25   29.9  µg/m³
# 6282        7002     MILITARY PARK      pm25   28.8  µg/m³
# 6283        7002     MILITARY PARK      pm25   29.8  µg/m³
#
#                                            coordinates country  city  \
# 0         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 1         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 2         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 3         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# 4         {'latitude': 42.3144, 'longitude': -83.0433}      US  None
# ...                                                ...     ...   ...
# 6279  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6280  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6281  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6282  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
# 6283  {'latitude': 42.312078, 'longitude': -83.103469}      US  None
#
#       isMobile isAnalysis                     entity       sensorType  \
# 0        False       None  Governmental Organization  reference grade
# 1        False       None  Governmental Organization  reference grade
# 2        False       None  Governmental Organization  reference grade
# 3        False       None  Governmental Organization  reference grade
# 4        False       None  Governmental Organization  reference grade
# ...        ...        ...                        ...              ...
# 6279     False       None  Governmental Organization  reference grade
# 6280     False       None  Governmental Organization  reference grade
# 6281     False       None  Governmental Organization  reference grade
# 6282     False       None  Governmental Organization  reference grade
# 6283     False       None  Governmental Organization  reference grade
#
#       sensor_lat  sensor_lon                local_time
# 0      42.314400  -83.043300 2023-06-06 19:00:00-04:00
# 1      42.314400  -83.043300 2023-06-06 18:00:00-04:00
# 2      42.314400  -83.043300 2023-06-06 17:00:00-04:00
# 3      42.314400  -83.043300 2023-06-06 16:00:00-04:00
# 4      42.314400  -83.043300 2023-06-06 15:00:00-04:00
# ...          ...         ...                       ...
# 6279   42.312078  -83.103469 2023-06-06 01:00:00-04:00
# 6280   42.312078  -83.103469 2023-06-06 00:00:00-04:00
# 6281   42.312078  -83.103469 2023-06-05 23:00:00-04:00
# 6282   42.312078  -83.103469 2023-06-05 22:00:00-04:00
# 6283   42.312078  -83.103469 2023-06-05 21:00:00-04:00
#
# [6284 rows x 15 columns]

# %% [markdown]
# #### Filter

# %%
def filter_openaq_data(transformed_data):
    filtered_data = transformed_data[['locationId', 'location', 'entity', 'parameter', 'value', 'local_time', 'sensor_lat', 'sensor_lon']]
    
    # Filter the data to include only Governmental Organization and Community Organization
    filtered_data = filtered_data[filtered_data['entity'].isin(['Governmental Organization', 'Community Organization'])]
    return filtered_data

filtered_data = filter_openaq_data(transformed_detroit_data)
filtered_data
# Out:
#       locationId          location                     entity parameter  \
# 0           1385  Windsor Downtown  Governmental Organization      pm25
# 1           1385  Windsor Downtown  Governmental Organization      pm25
# 2           1385  Windsor Downtown  Governmental Organization      pm25
# 3           1385  Windsor Downtown  Governmental Organization      pm25
# 4           1385  Windsor Downtown  Governmental Organization      pm25
# ...          ...               ...                        ...       ...
# 6279        7002     MILITARY PARK  Governmental Organization      pm25
# 6280        7002     MILITARY PARK  Governmental Organization      pm25
# 6281        7002     MILITARY PARK  Governmental Organization      pm25
# 6282        7002     MILITARY PARK  Governmental Organization      pm25
# 6283        7002     MILITARY PARK  Governmental Organization      pm25
#
#       value                local_time  sensor_lat  sensor_lon
# 0     125.0 2023-06-06 19:00:00-04:00   42.314400  -83.043300
# 1      21.0 2023-06-06 18:00:00-04:00   42.314400  -83.043300
# 2      14.0 2023-06-06 17:00:00-04:00   42.314400  -83.043300
# 3      18.0 2023-06-06 16:00:00-04:00   42.314400  -83.043300
# 4      21.0 2023-06-06 15:00:00-04:00   42.314400  -83.043300
# ...     ...                       ...         ...         ...
# 6279   33.7 2023-06-06 01:00:00-04:00   42.312078  -83.103469
# 6280   31.7 2023-06-06 00:00:00-04:00   42.312078  -83.103469
# 6281   29.9 2023-06-05 23:00:00-04:00   42.312078  -83.103469
# 6282   28.8 2023-06-05 22:00:00-04:00   42.312078  -83.103469
# 6283   29.8 2023-06-05 21:00:00-04:00   42.312078  -83.103469
#
# [6284 rows x 8 columns]

# %% [markdown]
# #### Store

# %%
# Save the filtered data to a new CSV file
filtered_data.to_csv('20230606_detroit_downtown_7_5km_aq.csv', index=False)
print("Data filtered and saved successfully!")
# Out:
# Data filtered and saved successfully!

# %%
# Load the data 
detroit_downtown_data = pd.read_csv('20230606_detroit_downtown_7_5km_aq.csv')
detroit_downtown_data
# Out:
#       locationId          location                     entity parameter  \
# 0           1385  Windsor Downtown  Governmental Organization      pm25
# 1           1385  Windsor Downtown  Governmental Organization      pm25
# 2           1385  Windsor Downtown  Governmental Organization      pm25
# 3           1385  Windsor Downtown  Governmental Organization      pm25
# 4           1385  Windsor Downtown  Governmental Organization      pm25
# ...          ...               ...                        ...       ...
# 6279        7002     MILITARY PARK  Governmental Organization      pm25
# 6280        7002     MILITARY PARK  Governmental Organization      pm25
# 6281        7002     MILITARY PARK  Governmental Organization      pm25
# 6282        7002     MILITARY PARK  Governmental Organization      pm25
# 6283        7002     MILITARY PARK  Governmental Organization      pm25
#
#       value                 local_time  sensor_lat  sensor_lon
# 0     125.0  2023-06-06 19:00:00-04:00   42.314400  -83.043300
# 1      21.0  2023-06-06 18:00:00-04:00   42.314400  -83.043300
# 2      14.0  2023-06-06 17:00:00-04:00   42.314400  -83.043300
# 3      18.0  2023-06-06 16:00:00-04:00   42.314400  -83.043300
# 4      21.0  2023-06-06 15:00:00-04:00   42.314400  -83.043300
# ...     ...                        ...         ...         ...
# 6279   33.7  2023-06-06 01:00:00-04:00   42.312078  -83.103469
# 6280   31.7  2023-06-06 00:00:00-04:00   42.312078  -83.103469
# 6281   29.9  2023-06-05 23:00:00-04:00   42.312078  -83.103469
# 6282   28.8  2023-06-05 22:00:00-04:00   42.312078  -83.103469
# 6283   29.8  2023-06-05 21:00:00-04:00   42.312078  -83.103469
#
# [6284 rows x 8 columns]

# %% [markdown]
# ### Perfom basic data analysis in Python using OpenAQ weather data.

# %%
detroit_downtown_data.isnull().sum()
# Out:
# locationId    0
# location      0
# entity        0
# parameter     0
# value         0
# local_time    0
# sensor_lat    0
# sensor_lon    0
# dtype: int64

# %%
detroit_downtown_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   locationId  6284 non-null   int64
#  1   location    6284 non-null   object
#  2   entity      6284 non-null   object
#  3   parameter   6284 non-null   object
#  4   value       6284 non-null   float64
#  5   local_time  6284 non-null   object
#  6   sensor_lat  6284 non-null   float64
#  7   sensor_lon  6284 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 392.9+ KB

# %% [markdown]
# #### § Task: Load your Detroit data and answer the following questions

# %%
def calculate_openaq_statistics(openaq_data):
    statistics = {}
    # 1. What is the mean and median PM2.5 reading over all sensors?
    statistics['PM25_Mean'] = openaq_data['value'].mean()
    statistics['PM25_Median'] = openaq_data['value'].median()

    # 2. What is the standard deviation?
    statistics['Standard_deviation'] = openaq_data['value'].std()

   # 3. Which location_id recorded the highest PM2.5? What was the reading?
    max_pm25_row = openaq_data.loc[openaq_data['value'].idxmax()]
    statistics['highest_PM25_location_id'] = max_pm25_row['locationId']
    statistics['highest_PM25'] = max_pm25_row['value']

    # 4. What is the ratio of Community Organization to Governmental Organization entity type?
    entity_counts = openaq_data['entity'].value_counts(normalize=True)
    statistics['ratio_community_to_government'] = entity_counts.get('Community Organization', 0) / entity_counts.get('Governmental Organization', 1)

    # 5. How many unique sensor stations are in the data (use locationId)?
    statistics['unique_sensor_stations'] = openaq_data['locationId'].nunique()

    # 6. What is the station density per km?
    area_km = 7.5  # Assuming the area is 7.5 km as mentioned
    statistics['station_density_per_km'] = statistics['unique_sensor_stations'] / area_km

    return statistics

statistics = calculate_openaq_statistics(detroit_downtown_data)
for key, value in statistics.items():
    print(f"{key}: {value}")
# Out:
# PM25_Mean: 66.0975970719287
# PM25_Median: 37.05
# Standard_deviation: 216.46080063153576
# highest_PM25_location_id: 65949
# highest_PM25: 1759.5
# ratio_community_to_government: 67.30434782608695
# unique_sensor_stations: 15
# station_density_per_km: 2.0

# %%
# 7. What is the daily mean, median, min, max, 75%, and standard deviation separately for all Community Organization and Government Organization 
# sensors in the data (that is group each separately and report the statistics being asked)?
# Converting local_time to datetime as the datatype is an object 
detroit_downtown_data_copy = detroit_downtown_data.copy()
detroit_downtown_data_copy['local_time'] = pd.to_datetime(detroit_downtown_data_copy['local_time']).dt.date

# Group data by 'entity' and 'local_time' column
grouped_data = detroit_downtown_data_copy.groupby(['local_time', 'entity'])

# Calculate statistics for each group
statistics = grouped_data['value'].agg(['mean', 'median', 'min', 'max', lambda x: x.quantile(0.75), 'std'])

# Rename columns for clarity
statistics.columns = ['Mean', 'Median', 'Min', 'Max', '75th Percentile', 'Standard Deviation']

# Set 'entity' as the index
statistics.reset_index(inplace = True)

# Rearrange columns
statistics = statistics[['entity', 'local_time', 'Mean', 'Median', 'Min', 'Max', '75th Percentile', 'Standard Deviation']]

# Display the statistics for all Community Organization and Government Organization sensors in a tabular format
statistics
# Out:
#                       entity  local_time       Mean  Median   Min     Max  \
# 0     Community Organization  2023-06-05  34.081768   35.70  21.3    49.6
# 1  Governmental Organization  2023-06-05  28.458333   28.55  26.4    30.3
# 2     Community Organization  2023-06-06  73.460674   38.50   6.1  1759.5
# 3  Governmental Organization  2023-06-06  36.410000   35.75  14.0   125.0
#
#    75th Percentile  Standard Deviation
# 0           37.700            5.645283
# 1           29.200            1.244960
# 2           46.500          239.515061
# 3           46.825           15.392811

# %% [markdown]
# ### PM2.5 Analysis
# - The **Mean** is slightly higher than **Median** indicating that the distribution of PM2.5 is slightly towards higher values or it outliers could be present.
# - The large **Standard deviation** could indicate wide variability of PM2.5 readings.
# - The **Highest PM2.5** reading occurred at location ID: 65949 with a value: 1759.5 indicating severe pollution or high emissions.
# - The **Ratio of Community Organization to Governmental Organization** is approximately 67.3 which indicates a greater number of readings from community organizations than government organization sensors.
# - There are 15 **unique sensors** with **station density** of 2.0 per km.

# %% [markdown]
# ##### 8. What is your opinion of the differences in the statistics? Comment specifically about the mean and 75%.
# - The **mean PM2.5** recorded by the community organization sensors tends to be **higher** than government organization sensors on both dates. This indicates that the community sensors may be exposed to higher pollution levels or present in greater pollution sources compared to the government sensors.
# - The 75th percentile value represents the value below which 75% of the data falls. Community organization sensors exhibit a **higher 75% percentile value** compared to government organization sensors on both dates. This indicates that the community sensors may be exposed to higher pollution levels or present in greater pollution sources compared to the government sensors.

# %% [markdown]
# ### § Task: Build a map of the stations

# %%
# # Plotting the map 
# detroit_map = folium.Map(
#     location = [42.33143,-83.04575],
#     zoom_start = 12,
# )

# folium.Marker(
#     [42.3314,-83.04575],
#     popup = "Downtown Detroit",
#     icon = folium.Icon(color = 'blue', icon = 'city', prefix = 'fa')).add_to(detroit_map)

# # Iterating through the dataset 
# for index, row in detroit_downtown_data.iterrows():
#     if row['entity'] == "Community Organization":
#         # Green Pin for Community organization sensors
#         folium.Marker(
#             [row['sensor_lat'], row['sensor_lon']],
#             popup = f"{row['location']} (Community)",
#             icon = folium.Icon(color = 'green', icon = 'info-sign', prefix = 'glyphicon')).add_to(detroit_map)
#     elif row['entity'] == "Governmental Organization":
#         # Red Pin for Government organization sensors
#         folium.Marker(
#             [row['sensor_lat'], row['sensor_lon']],
#             popup = f"{row['location']} (Government)",
#             icon = folium.Icon(color = 'red', icon = 'asterisk', prefix = 'glyphicon')).add_to(detroit_map)

# detroit_map.save('detroit_map.html')
# detroit_map

# %% [markdown]
# ### § Task: Explore hourly averages for the day

# %%
# Function to find hourly averages 
def process_detroit_downtown_data(data):
    # Convert 'local_time' to datetime format
    data['local_time'] = pd.to_datetime(data['local_time'], utc=True)

    # Define the 6-hour blocks
    blocks = [(0, 6), (6, 12), (12, 18), (18, 24)]

    # Create a function to categorize the hour into the corresponding block
    def categorize_hour(hour):
        for block in blocks:
            if block[0] <= hour < block[1]:
                return block

    # Categorize each hour into the corresponding block
    data['block'] = data['local_time'].dt.hour.apply(categorize_hour)

    # Group by 'entity' and 'block', then calculate the average readings for each group
    average_readings = data.groupby(['entity', 'block'])['value'].mean().reset_index(name = 'Average Reading')

    # Extract hour from 'local_time'
    data['hour'] = detroit_downtown_data['local_time'].dt.hour

    # Group by 'entity' and 'hour', then calculate the average readings for each group
    hourly_avg = data.groupby(['entity', 'hour'])['value'].mean().reset_index(name = 'Hourly average')

    # Plotting the hourly averages for the day
    plt.figure(figsize=(12, 6))
    for entity in hourly_avg['entity'].unique():
        entity_data = hourly_avg[hourly_avg['entity'] == entity]
        color = 'blue' if entity == 'Governmental Organization' else 'orange'
        plt.plot(entity_data['hour'], entity_data['Hourly average'], label = entity, color = color)

    plt.title("Hourly PM2.5 Averages for June 6, 2023 (Detroit, MI)")
    plt.xlabel("Hour (0-23)")
    plt.ylabel("PM2.5 Value")
    plt.legend(title = "Sensor Type")
    plt.xticks(range(24))
    plt.show()

    return average_readings

# %%
average_readings_detroit = process_detroit_downtown_data(detroit_downtown_data)
average_readings_detroit
# Out:
#                       entity     block  Average Reading
# 0     Community Organization    (0, 6)        35.095077
# 1     Community Organization   (6, 12)        62.490485
# 2     Community Organization  (12, 18)       118.638343
# 3     Community Organization  (18, 24)        50.021926
# 4  Governmental Organization    (0, 6)        29.910000
# 5  Governmental Organization   (6, 12)        41.312500
# 6  Governmental Organization  (12, 18)        40.312500
# 7  Governmental Organization  (18, 24)        29.045833

# %% [markdown]
# ### The average Reading for each of the 6-hour blocks
# - 0 - 6
#     - Community Organization Sensor: 35.095077
#     - Governmental Organization Sensor: 29.910000
# - 6 - 12
#     - Community Organization Sensor: 62.490485
#     - Governmental Organization Sensor: 41.312500
# - 12 - 18
#     - Community Organization Sensor: 118.638343
#     - Governmental Organization Sensor: 40.312500
# - 18 - 24
#     - Community Organization Sensor: 50.021926
#     - Governmental Organization Sensor: 29.045833

# %% [markdown]
# ### Compare and Contrast Readings
# - The reading indicates that the PM2.5 readings are higher during the daytime(6am - 6pm) than the nighttime(6pm - 6am) which means the higher pollutant emissions during the day.
# - The significant increase in reading during noon - 6 pm in community sensors indicates peak traffic and other activities leading to higher pollutant emissions.
# - The reading of the government organization sensors is stable across different periods.
# - Community Organization sensors tend to have higher readings compared to Government Organization sensors across all periods.

# %% [markdown]
# ## Perfom basic statistical significance tests of air quality data.

# %% [markdown]
# ### § Task: Determine if the sensor means for the day are different, and if that difference is statistically significant.

# %%
# Filter data for community and government sensors
community_data = detroit_downtown_data[detroit_downtown_data['entity'] == 'Community Organization']
government_data = detroit_downtown_data[detroit_downtown_data['entity'] == 'Governmental Organization']

# 1. In this task, first, build a dataset with 95 data points sampled from 100 random draws of data from the community sensors:
    # • an easy way to do this is with the DataFrame.sample(), with 95 as the parameter
    # • you can then loop 100 times and average over all those loops
    # • you may want to just concatenate the 100 draws to a 100 column by 95-row DataFrame and compute the mean(), but there are other ways
# Sample 95 data points from the community sensors, 100 times
community_samples = pd.DataFrame([community_data['value'].sample(n = 95) for _ in range(100)])
community_sample_mean = community_samples.mean(axis = 0)

# 2. What are the descriptive statistics of your sample and the government data?
# Descriptive statistics for the community sample and the government data
community_stats = community_sample_mean.describe()
government_stats = government_data['value'].describe()

# 3. Compare and contrast, bring attention to the mean, 75%, and standard deviations.
# 4. Run a test for normality on the two samples using scipy.stats.normaltest().
    # • Can you fail to reject the null hypothesis (that the samples are drawn from normal distributions) at 𝛼 = 0.05?
    # • You will only need to look at the p-value
# Test for normality
community_normality = stats.normaltest(community_sample_mean)
government_normality = stats.normaltest(government_data['value'])

# 5. Run a Barlett test for equal variances (also known as homoscedasticity). You will only need to look at the p-value.
    # • Can you fail to reject the null hypothesis (that the samples have equal variances) at 𝛼 = 0.05?
# Test for equal variances
variance_test = stats.bartlett(community_sample_mean, government_data['value'])

# 6. Run the independent t-test, and use the result in the parameter equal_var=. That is if you fail to reject the null hypothesis from Bartlett’s then equal_var=True.
    # • Can you fail to reject the null hypothesis(that the means of two independent samples have identical average expected values) at 𝛼 = 0.001? 
    # (Notice we have raised the bar for statistical significance!)
    # • Make sure your notebook emits the p-value of the t-test.
# Independent t-test
t_test_result = stats.ttest_ind(community_sample_mean, government_data['value'], equal_var = (variance_test.pvalue > 0.05))


# Output the results
print("Community Sensor Sample Descriptive Statistics:\n", community_stats)
print("\nGovernment Sensor Data Descriptive Statistics:\n", government_stats)
print("\nNormality Test Results:")
print("Community Sensor Sample p-value:", community_normality.pvalue)
print("Government Sensor Data p-value:", government_normality.pvalue)
print("\nBartlett Test for Equal Variances p-value:", variance_test.pvalue)
print("\nIndependent T-Test Results:")
print("T-test p-value:", t_test_result.pvalue)

# Check if we can fail to reject the null hypotheses
normality_community = "Fail to reject" if community_normality.pvalue > 0.05 else "Reject"
normality_government = "Fail to reject" if government_normality.pvalue > 0.05 else "Reject"
equal_variances = "Fail to reject" if variance_test.pvalue > 0.05 else "Reject"
mean_difference = "Fail to reject" if t_test_result.pvalue > 0.001 else "Reject"

print("\nCan we fail to reject the null hypothesis for normality (Community)?", normality_community)
print("Can we fail to reject the null hypothesis for normality (Government)?", normality_government)
print("Can we fail to reject the null hypothesis for equal variances?", equal_variances)
print("Can we fail to reject the null hypothesis for mean difference?", mean_difference)
# Out:
# Community Sensor Sample Descriptive Statistics:
#  count    4925.000000
# mean       67.584548
# std       221.910829
# min         6.100000
# 25%        28.800000
# 50%        37.100000
# 75%        45.000000
# max      1759.500000
# dtype: float64
#
# Government Sensor Data Descriptive Statistics:
#  count     92.000000
# mean      35.372826
# std       14.599030
# min       14.000000
# 25%       27.700000
# 50%       33.300000
# 75%       43.850000
# max      125.000000
# Name: value, dtype: float64
#
# Normality Test Results:
# Community Sensor Sample p-value: 0.0
# Government Sensor Data p-value: 4.8019743658509495e-18
#
# Bartlett Test for Equal Variances p-value: 1.6777638731889045e-89
#
# Independent T-Test Results:
# T-test p-value: 1.0963769054611847e-19
#
# Can we fail to reject the null hypothesis for normality (Community)? Reject
# Can we fail to reject the null hypothesis for normality (Government)? Reject
# Can we fail to reject the null hypothesis for equal variances? Reject
# Can we fail to reject the null hypothesis for mean difference? Reject

# %% [markdown]
# #### Analysis findings
# ##### Descriptive Statistics of your sample and the government data
#
# - Community Organization
#     - Mean: 67.584548
#     - 75th Percentile: 45
#     - Standard Deviation: 221.910829
#
# - Government Organization
#     - Mean: 35.37
#     - 75th Percentile: 43.85
#     - Standard Deviation: 14.59
#
# ##### Compare and Contrast
# - The mean PM2.5 value of the community sensor sample is significantly higher than that of the government sensors.
# - The standard deviation of the community sensor sample is substantially larger than that of the government sensors, indicating a wider spread of values
# - The 75th percentile is slightly higher for the community sensors, suggesting that the upper quartile of community sensor readings is higher.
#
# #### Tests
# ##### Normality Test
# - The community sensor p-value is extremely small (close to zero) which is below the alpha value of 0.05, indicating that the community sensor data is not normally distributed.
# - The Government sensor p-value is also extremely small much smaller than the alpha value of 0.05, indicating that the data is also not normally distributed.
#
# ##### Bartlett Test for Equal Variances
# - The p-value is extremely small suggesting that the variance of the two samples(community and government) are not equal.
#
# ##### Independent T-test
# - The p-value is extremely small than the alpha value of 0.001. We reject the null hypothesis and conclude that the means of the independent samples(community and government sensor data) are significantly different.
#
# In summary
# - The community and government sensor data are not normally distributed.
# - The variance of the samples is not equal.
# - The means of the two samples are significantly different.

# %%
# Group the data by locationId and entity, then count the number of unique sensors
unique_sensors = detroit_downtown_data.groupby(['locationId', 'entity']).size().reset_index(name = 'sensor_count')

# Print the unique sensors and their corresponding entity types
print("Unique Sensors and Their Entity Types:")
unique_sensors
# Out:
# Unique Sensors and Their Entity Types:
#     locationId                     entity  sensor_count
# 0         1385  Governmental Organization            23
# 1         2143  Governmental Organization            23
# 2         7001  Governmental Organization            23
# 3         7002  Governmental Organization            23
# 4        64955     Community Organization           668
# 5        65004     Community Organization           649
# 6        65949     Community Organization           651
# 7        70433     Community Organization           658
# 8        72889     Community Organization            11
# 9       221037     Community Organization           626
# 10      222034     Community Organization           650
# 11      222451     Community Organization           649
# 12      234610     Community Organization           675
# 13      354096     Community Organization           314
# 14      357488     Community Organization           641

# %% [markdown]
# ### § Task: Go to the course Blackboard and complete the assessment.

# %% [markdown]
# #### 1. What is your reaction to the statement: Community sensors detected the poor air quality of the 2023 Canadian wildfires better than Government sensors
# - **Reaction**:
#     - The data observed from the analysis shows that the community sensors have recorded higher values than the government sensors during the time analyzed.
#     - The mean PM2.5 reading from the community sensors was 73.46 while the government sensor was 36.41. This suggests that community sensors may have been more sensitive or more numerous in areas affected by the wildfire, leading to higher readings.
#     - The standard deviation for community sensors is significantly higher compared to government sensors, indicating a wider spread of data.
#     - It could be due to many factors like sensor placement, and local environmental conditions.
#     - The ratio of community to government sensors is approximately 67.3, indicating a higher density of community sensors. This might be contributing to higher readings, as a higher density of sensors increases the likelihood of detecting localized spikes in PM2.5 levels.
# #### 2. What is your reaction to the statement: There need to be more community sensors deployed in downtown Detroit.
# - **Reaction**:
#     - The provided data shows that there are 15 unique sensor stations in the area, with a station density of 2.0 per km.
#     - The ratio of community to government sensors is approximately 67.3, suggesting that community sensors already make up a significant proportion of the total sensors.
#     - However, whether more sensors are needed would depend on a variety of factors that are not present in the data.

# %% [markdown]
# ### (5 extra points) BONUS: Build and analyze a more complex OpenAQ data set.

# %% [markdown]
# ### § Task: Build the OpenAQ dataset for 2023 for JFK airport in New York City

# %% [markdown]
# ### § Task: Analyze the data and answer the questions
